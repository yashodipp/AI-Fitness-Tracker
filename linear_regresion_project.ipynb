# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
# 1 Load Your Data
df = pd.read_csv('gym_members_exercise_tracking.csv')

# %%
df.head()
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   56    Male         88.3        1.71      180      157           60
# 1   46  Female         74.9        1.53      179      151           66
# 2   32  Female         68.1        1.66      167      122           54
# 3   25    Male         53.2        1.70      190      164           56
# 4   38    Male         46.1        1.79      188      158           68
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
# 3                      0.59            532.0     Strength            28.8
# 4                      0.64            556.0     Strength            29.2
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                    3.5                              4                 3
# 1                    2.1                              4                 2
# 2                    2.3                              4                 2
# 3                    2.1                              3                 1
# 4                    2.8                              3                 1
#
#      BMI
# 0  30.20
# 1  32.00
# 2  24.71
# 3  18.41
# 4  14.39

# %%
# How we will  perform EDA
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            973 non-null    int64
#  1   Gender                         973 non-null    object
#  2   Weight (kg)                    973 non-null    float64
#  3   Height (m)                     973 non-null    float64
#  4   Max_BPM                        973 non-null    int64
#  5   Avg_BPM                        973 non-null    int64
#  6   Resting_BPM                    973 non-null    int64
#  7   Session_Duration (hours)       973 non-null    float64
#  8   Calories_Burned                973 non-null    float64
#  9   Workout_Type                   973 non-null    object
#  10  Fat_Percentage                 973 non-null    float64
#  11  Water_Intake (liters)          973 non-null    float64
#  12  Workout_Frequency (days/week)  973 non-null    int64
#  13  Experience_Level               973 non-null    int64
#  14  BMI                            973 non-null    float64
# dtypes: float64(7), int64(6), object(2)
# memory usage: 114.2+ KB

# %%
# 1. Gender
# 2. Workout Type
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Workout_Type'].unique()
# Out:
# array(['Yoga', 'HIIT', 'Cardio', 'Strength'], dtype=object)

# %%
# 2. TO check null Values
df.isnull().sum()
# Out:
# Age                              0
# Gender                           0
# Weight (kg)                      0
# Height (m)                       0
# Max_BPM                          0
# Avg_BPM                          0
# Resting_BPM                      0
# Session_Duration (hours)         0
# Calories_Burned                  0
# Workout_Type                     0
# Fat_Percentage                   0
# Water_Intake (liters)            0
# Workout_Frequency (days/week)    0
# Experience_Level                 0
# BMI                              0
# dtype: int64

# %%
# Checking Target Colums (Calorise_burned)for skewness
sns.histplot(df['Calories_Burned'],kde=True)
# Out:
# <Axes: xlabel='Calories_Burned', ylabel='Count'>

# %%
df['Calories_Burned'].skew()
# Out:
# np.float64(0.2783210950013363)

# %%
# Coorelation Heatmap Between numerical feature.
corr = df.corr(numeric_only=True)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
# Gender, Workout_Type encode
df['Gender'] = df['Gender'].map({'Male':0,'Female':1})

# %%
# Workout_Type OneHot Encode
df = pd.get_dummies(df,columns=['Workout_Type'])

# %%
# Split X and y Variables
X = df.drop('Calories_Burned',axis=1)
y = df['Calories_Burned']

# %%
# Train Test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)   #To prevent from data leakage.

# %%
# Build linear Regression model
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = linear_model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

print(f"Testing Accurecy : r2_score(y_test,y_pred)")
# Out:
# Testing Accurecy : r2_score(y_test,y_pred)

# %%
print(f" Training Accurecy :r2_score(y_train,linear_model.predict(X_train)")
# Out:
#  Training Accurecy :r2_score(y_train,linear_model.predict(X_train)

# %%
mae = mean_absolute_error(y_test,y_pred)

# %%
mae
# Out:
# 30.270139845320685

# %%
import joblib
joblib.dump(linear_model,'linear_model.pkl')
# Out:
# ['linear_model.pkl']
